# %%
from openai import OpenAI
from dotenv import load_dotenv
import os
import requests
from PyPDF2 import PdfReader
import gradio as gr
import json

# %%
load_dotenv(override=True)
# Out:
# True

# %%
reader=PdfReader(r"C:\Users\anike\Documents\agents\avatar\aniket resume-updated.pdf")
linkedin=""
for page in reader.pages:
    text=page.extract_text()
    if text:
        linkedin+=text

with open(r"C:\Users\anike\Documents\agents\avatar\summary.txt","r",encoding="utf-8") as f:
    summary=f.read()

name="Aniket Sharma"

# %%
system_prompt = f"""You are acting as {name}. You are answering questions on {name}'s website, particularly questions related to {name}'s career, background, skills and experience.

Your responsibility is to represent {name} for interactions on the website as faithfully as possible.

You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions.

Be professional and engaging, as if talking to a potential client or future employer who came across the website.

If you don't know the answer to any question, use your record_unknown_question tool to record the question that you couldn't answer.

If the user is engaging in discussion, try to steer them towards getting in touch via email; ask for their email and record it using your record_user_details tool.
"""

system_prompt += f"""

## Summary:
{summary}

## LinkedIn Profile:
{linkedin}

"""

system_prompt += f"""
With this context, please chat with the user, always staying in character as {name}.
"""

# %%
gemini = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def chat_msg(message,history):
    messages=[{"role":"system", "content":system_prompt}] + history + [{"role":"user","content":message}]
    done=False
    while not done:
        response=gemini.chat.completions.create(model="gemini-2.5-flash", messages=messages)
        done=True

    return response.choices[0].message.content

# %%
gr.ChatInterface(chat_msg).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\anike\Documents\agents\avatar\.venv\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\Users\anike\Documents\agents\avatar\.venv\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# ...

# %%
print(gr.__version__)
# Out:
# 6.18.0
